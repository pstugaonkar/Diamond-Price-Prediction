# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
data.isna().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
cat_columns=list(data.columns[data.dtypes == 'object'])

# %%
cat_columns
# Out:
# ['cut', 'color', 'clarity']

# %%
num_columns=list(data.columns[data.dtypes!='object'])

# %%
num_columns
# Out:
# ['id', 'carat', 'depth', 'table', 'x', 'y', 'z', 'price']

# %%
for i in num_columns:
    sns.histplot(data=data,x=i,kde=True)
    plt.title('Histograph')
    plt.show()

# %%
cat_columns
# Out:
# ['cut', 'color', 'clarity']

# %%
for i in cat_columns:
    data[i].value_counts().plot(kind='bar')
    plt.show()

# %%
sns.pairplot(data,diag_kind='kde')
plt.show()

# %%
cat_columns
# Out:
# ['cut', 'color', 'clarity']

# %%
for i in cat_columns:
    sns.boxplot(data=data,x=i,y='price')
    plt.show()

# %%
cut_mapper = {"Fair":1, "Good":2, "Very Good":3 , "Premium":4 ,"Ideal":5}
clarity_mapper = {"I1":1,"SI2":2 ,"SI1":3 ,"VS2":4 , "VS1":5 , "VVS2":6 , "VVS1":7 ,"IF":8}
color_mapper = {"D":1 ,"E":2 ,"F":3 , "G":4 ,"H":5 , "I":6, "J":7}

# %%
data['cut'] = data['cut'].replace(cut_mapper)
data['clarity'] = data['clarity'].replace(clarity_mapper)
data['color'] = data['color'].replace(color_mapper)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_15236\3933239445.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['cut'] = data['cut'].replace(cut_mapper)
# C:\Users\admin\AppData\Local\Temp\ipykernel_15236\3933239445.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['clarity'] = data['clarity'].replace(clarity_mapper)
# C:\Users\admin\AppData\Local\Temp\ipykernel_15236\3933239445.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['color'] = data['color'].replace(color_mapper)

# %%
data.head()
# Out:
#    id  carat  cut  color  clarity  depth  table     x     y     z  price
# 0   0   1.52    4      3        4   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03    3      7        2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70    5      4        5   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32    5      4        5   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    4      4        4   62.6   59.0  7.65  7.61  4.77  14453
